# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset

# %%
df = pd.read_csv("bearing_data.csv")

print(f"shape: {df.shape}")
print(f"columns: {df.columns}")

print(f"null values count:\n{df.isnull().sum()}")
# Out:
# shape: (1115, 3)
# columns: Index(['Fr', 'n', 'Lifetime'], dtype='object')
# null values count:
# Fr          0
# n           0
# Lifetime    0
# dtype: int64

# %% [markdown]
# ### Plotting

# %%
fig1, axs1 = plt.subplots(ncols=3, figsize=(10,5))
sns.histplot(data=df, x="Fr", ax=axs1[0])
sns.histplot(data=df, x="n", ax=axs1[1])
sns.histplot(data=df, x="Lifetime", ax=axs1[2])
plt.show()

# %%
fig2, axs2 = plt.subplots(3, sharex=True, figsize=(15, 15))
axs2[0].plot(df['n'])
axs2[0].set_title('n')
axs2[1].plot(df['Fr'])
axs2[1].set_title('Fr')
axs2[2].plot(df['Lifetime'])
axs2[2].set_title('Lifetime')
# Out:
# Text(0.5, 1.0, 'Lifetime')

# %%
print(df.describe())
# Out:
#                 Fr            n       Lifetime
# count  1115.000000  1115.000000    1115.000000
# mean   2456.950673  1806.726457    8137.672225
# std     919.923906  1007.601072   23611.384236
# min     900.000000   100.000000     116.370093
# 25%    1700.000000   900.000000     519.707366
# 50%    2500.000000  1800.000000    1585.948449
# 75%    3300.000000  2700.000000    6166.340855
# max    4000.000000  3500.000000  413786.257700

# %% [markdown]
# ### Correlations

# %%
corr = df.corr()
sns.heatmap(corr, annot=True)
plt.show()

# %% [markdown]
# ### Variable relationships

# %%
sns.pairplot(data=df)
plt.show()

# %%
sns.regplot(x='Fr', y='Lifetime', data=df)
plt.show()
